# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### **Задание 1**
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
# - если источник traffic_source равен yandex или google, то в source_type ставится organic
# - для источников paid и email из России - ставим ad
# - для источников paid и email не из России - ставим other
# - все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd

# %%
log = pd.read_csv('visit_log.csv', sep=';')
log.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %%
# %%time

log.loc[log.traffic_source.isin(['yandex', 'google']), 'traffic_type'] = 'organic'
log.loc[(log.traffic_source.isin(['paid', 'email'])) & (log.region == 'Russia'), 'traffic_type'] = 'ad'
log.loc[(log.traffic_source.isin(['paid', 'email'])) & (log.region != 'Russia'), 'traffic_type'] = 'other'
log.loc[(~log.traffic_source.isin(['yandex', 'google'])) & (~log.traffic_source.isin(['paid', 'email'])) , 'traffic_type'] = log.traffic_source
log.head(10)
# Out:
# Wall time: 32 ms
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
# 5  1549980742  8855508aad  https://host.ru/df646c3676cc259fa0  Russia
# 6  1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15  Russia
# 7  1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e  Russia
# 8  1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867   China
# 9  1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0  Russia
#
#       user_id traffic_source traffic_type
# 0  b1613cc09f         yandex      organic
# 1  4c3ec14bee         direct       direct
# 2  a8c40697fb         yandex      organic
# 3  521ac1d6a0         yandex      organic
# 4  d7323c571c         yandex      organic
# 5  fc43898e47         yandex      organic
# 6  13fc55e781           paid           ad
# 7  cb5082b6f6         direct       direct
# 8  45664f7af2         direct       direct
# 9  6f9de8c8b6          email           ad

# %%
def type_of_traffic(row):
    traffic_source = row['traffic_source']
    region = row['region']
    if traffic_source in ['yandex', 'google']:
        return 'organic'
    elif (traffic_source in ['paid', 'email']) & (region == 'Russia'):
        return 'ad'
    elif (traffic_source in ['paid', 'email']) & (region != 'Russia'):
        return 'other'
    else:
        return traffic_source

# %%
# %%time

log2 = pd.read_csv('visit_log.csv', sep=';')
log2['traffic_type']= log2.apply(type_of_traffic, axis=1)
log2.head(10)
# Out:
# Wall time: 549 ms
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
# 5  1549980742  8855508aad  https://host.ru/df646c3676cc259fa0  Russia
# 6  1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15  Russia
# 7  1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e  Russia
# 8  1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867   China
# 9  1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0  Russia
#
#       user_id traffic_source traffic_type
# 0  b1613cc09f         yandex      organic
# 1  4c3ec14bee         direct       direct
# 2  a8c40697fb         yandex      organic
# 3  521ac1d6a0         yandex      organic
# 4  d7323c571c         yandex      organic
# 5  fc43898e47         yandex      organic
# 6  13fc55e781           paid           ad
# 7  cb5082b6f6         direct       direct
# 8  45664f7af2         direct       direct
# 9  6f9de8c8b6          email           ad

# %% [markdown]
# ### **Задание 2**
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
# 1. Прочитайте содержимое файла с датафрейм
# 2. Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
url = pd.read_csv('URLs.txt')
url.head()
# Out:
#                                                  url
# 0                                            /world/
# 1                                           /latest/
# 2                                      /?updated=top
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %%
url[url.url.str.contains('\d{8}-')].head(20)
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 10  /middleeast/36131117-divizion-s-400-ne-zametil...
# 11  /economics/36065674-rossiyane-vozmutilis-minim...
# 12  /politics/36118047-otets-24-detey-potreboval-i...
# 13  /travel/36194479-v-sheremetevo-passazhiry-ustr...
# 14  /politics/35638742-nesolidno-mariya-zaharova-s...
# 15  /video/36012692-tramp-otkrestilsya-ot-rossii-i...
# 16     /starlife/36174817-guzeeva-rasstalas-s-muzhem/
# 17  /health/36149308-predlozheno-prostoe-sredstvo-...
# 18  /science/36139723-set-vzbudorazhila-novost-o-s...
# 19  /cis/36229699-poroshenko-obyavil-vseukrainskiy...
# 20  /incidents/36225203-tonnel-obrushilsya-v-novoy...
# 21  /politics/36118047-otets-24-detey-potreboval-i...
# 22  /world/36075956-na-granitse-s-krymom-zahvachen...
# 23  /politics/36115220-mid-vystupil-s-preduprezhde...
# 24  /world/36018565-sbu-opublikovala-zapis-peregov...

# %% [markdown]
# ### **Задание 3**
# В датафрейме data создайте столбец lemmas, в котором вычислите леммы поисковых запросов из столбца keyword. Леммы должны иметь строковый тип.

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})

# %%
data
# Out:
#                  keyword   shows
# 0    курс гривны к рублю  125076
# 1        доллары в рубли  114173
# 2  100 долларов в рублях   97534
# 3             курс рубля   53546

# %%
pip install pymystem3
# Out:
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in c:\users\fines\anaconda3\lib\site-packages (from pymystem3) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fines\anaconda3\lib\site-packages (from requests->pymystem3) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\fines\anaconda3\lib\site-packages (from requests->pymystem3) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\fines\anaconda3\lib\site-packages (from requests->pymystem3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\fines\anaconda3\lib\site-packages (from requests->pymystem3) (1.25.8)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymystem3 import Mystem

# %%
m = Mystem()

# %%
def lemma(row):
    keyword = row['keyword']
    return (''.join(m.lemmatize(keyword))).strip()

# %%
data['lemmas']= data.apply(lemma, axis=1)

# %%
data
# Out:
#                  keyword   shows               lemmas
# 0    курс гривны к рублю  125076  курс гривна к рубль
# 1        доллары в рубли  114173       доллар в рубль
# 2  100 долларов в рублях   97534   100 доллар в рубль
# 3             курс рубля   53546           курс рубль
